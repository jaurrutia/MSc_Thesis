# %%
<< "MaTeX`"
<< "~/Documents/Wolfram Mathematica/Wolfram_scripts/Optics_Mie.wls"
<< "~/Documents/Wolfram Mathematica/Wolfram_scripts/Optical_functions/Au_JohnsnChristy.wls"
<< "~/Documents/Wolfram Mathematica/Wolfram_scripts/jet_jet-extended.wls"

# %%
fs = 9;

texStyle := {FontFamily -> "Latin Modern Roman", FontSize -> fs, Black};
graphsOpts := {Mesh -> Full, BaseStyle -> texStyle, Frame -> True, 
            FrameStyle -> Black, ImageSize -> 215, PlotStyle -> ColorData[3]}
SetOptions[ListLinePlot, graphsOpts];

graphsOptsPolar := {Mesh -> Full, BaseStyle -> texStyle,  PolarAxes -> True ,
            FrameStyle -> Black, ImageSize -> 215, PlotStyle -> ColorData[3], Frame -> False, PolarGridLines -> Automatic, Joined -> True}
SetOptions[ListPolarPlot, graphsOptsPolar];

graphsOptsDensity := { BaseStyle -> texStyle, FrameStyle-> Black,
                        InterpolationOrder -> 1, PlotRange -> All, 
                        ColorFunctionScaling -> True, ColorFunction -> JetExtended, Mesh->None, ImageSize -> 150, PlotRangePadding -> None  }
SetOptions[ListDensityPlot, graphsOptsDensity];

# %% [markdown]
# ### Example E Field

# %%
nDrude = Sqrt@DrudeEpsEnergy[hcPlanckSpeed/#,10., 0.015]&;

radius = 30.;
mesh = N[Array[{#1,0.,#2}&,{50,50}, 3. * radius *{{1,-1},{1,-1}}]];
dataxz = {{0,0},{0,0}};

lda = 342.;
indices = {1.33, nDrude[lda]};
AbsoluteTiming[ dataxz[[1,1]] = MieScatteredElectricField[mesh,indices, lda, radius, "Parallelize" -> True];]
AbsoluteTiming[ dataxz[[1,2]] = MieInternalElectricField[mesh,indices, lda, radius, "Parallelize" -> True]; ]


lda = 262.;
indices = {1.33, nDrude[lda]};
AbsoluteTiming[ dataxz[[2,1]] = MieScatteredElectricField[mesh,indices, lda, radius, "Parallelize" -> True];]
AbsoluteTiming[ dataxz[[2,2]] = MieInternalElectricField[mesh,indices, lda, radius, "Parallelize" -> True]; ]

Map[ListDensityPlot[Map[Chop@Norm, #,{-2}]]&, dataxz, {2}]
Map[ListDensityPlot[Map[Chop@Norm, #,{-2}]]&, Plus @@@ dataxz]
# Out:
# {32.1605, Null}
# {3.41816, Null}
# {29.3025, Null}
# {3.18391, Null}
# {{-Graphics-, -Graphics-}, {-Graphics-, -Graphics-}}
# {-Graphics-, -Graphics-}

# %%
mesh = N[Array[{0.,#1,#2}&,{50,50}, 3. * radius *{{1,-1},{1,-1}}]];
datayz = {{0,0},{0,0}};

lda = 342.;
indices = {1.33, nDrude[lda]};
AbsoluteTiming[ datayz[[1,1]] = MieScatteredElectricField[mesh,indices, lda, radius, "Parallelize" -> True];]
AbsoluteTiming[ datayz[[1,2]] = MieInternalElectricField[mesh,indices, lda, radius, "Parallelize" -> True]; ]


lda = 262.;
indices = {1.33, nDrude[lda]};
AbsoluteTiming[ datayz[[2,1]] = MieScatteredElectricField[mesh,indices, lda, radius, "Parallelize" -> True];]
AbsoluteTiming[ datayz[[2,2]] = MieInternalElectricField[mesh,indices, lda, radius, "Parallelize" -> True]; ]

Map[ListDensityPlot[Map[Chop@Norm, #,{-2}]]&, datayz, {2}]
Map[ListDensityPlot[Map[Chop@Norm, #,{-2}]]&, Plus @@@ datayz]
# Out:
# {18.8601, Null}
# {2.10727, Null}
# {18.5396, Null}
# {2.19563, Null}
# {{-Graphics-, -Graphics-}, {-Graphics-, -Graphics-}}
# {-Graphics-, -Graphics-}

# %% [markdown]
# ### Example H Field

# %%
nDrude = Sqrt@DrudeEpsEnergy[hcPlanckSpeed/#,10., 0.015]&;

radius = 30.;
mesh = N[Array[{#1,0.,#2}&,{50,50}, 3. * radius *{{1,-1},{1,-1}}]];
dataxz = {{0,0},{0,0}};

lda = 342.;
indices = {1.33, nDrude[lda]};
AbsoluteTiming[ dataxz[[1,1]] = MieScatteredHField[mesh,indices, lda, radius, "Parallelize" -> True];]
AbsoluteTiming[ dataxz[[1,2]] = MieInternalHField[mesh,indices, lda, radius, "Parallelize" -> True]; ]


lda = 262.;
indices = {1.33, nDrude[lda]};
AbsoluteTiming[ dataxz[[2,1]] = MieScatteredHField[mesh,indices, lda, radius, "Parallelize" -> True];]
AbsoluteTiming[ dataxz[[2,2]] = MieInternalHField[mesh,indices, lda, radius, "Parallelize" -> True]; ]

Map[ListDensityPlot[Map[Chop@Norm, #,{-2}]]&, dataxz, {2}]
Map[ListDensityPlot[Map[Chop@Norm, #,{-2}]]&, Plus @@@ dataxz]
# Out:
# {18.8593, Null}
# {2.28755, Null}
# {19.9879, Null}
# {2.13816, Null}
# {{-Graphics-, -Graphics-}, {-Graphics-, -Graphics-}}
# {-Graphics-, -Graphics-}

# %%
mesh = N[Array[{0., #1,#2}&,{50,50}, 3. * radius *{{1,-1},{1,-1}}]];
datayz = {{0,0},{0,0}};

lda = 342.;
indices = {1.33, nDrude[lda]};
AbsoluteTiming[ datayz[[1,1]] = MieScatteredHField[mesh,indices, lda, radius, "Parallelize" -> True];]
AbsoluteTiming[ datayz[[1,2]] = MieInternalHField[mesh,indices, lda, radius, "Parallelize" -> True]; ]


lda = 262.;
indices = {1.33, nDrude[lda]};
AbsoluteTiming[ datayz[[2,1]] = MieScatteredHField[mesh,indices, lda, radius, "Parallelize" -> True];]
AbsoluteTiming[ datayz[[2,2]] = MieInternalHField[mesh,indices, lda, radius, "Parallelize" -> True]; ]

Map[ListDensityPlot[Map[Chop@Norm, #,{-2}]]&, datayz, {2}]
Map[ListDensityPlot[Map[Chop@Norm, #,{-2}]]&, Plus @@@ datayz]
# Out:
# {18.7771, Null}
# {2.2296, Null}
# {18.4234, Null}
# {2.34612, Null}
# {{-Graphics-, -Graphics-}, {-Graphics-, -Graphics-}}
# {-Graphics-, -Graphics-}

# %% [markdown]
# ## Dipolo

# %%
nDrude = Sqrt@DrudeEpsEnergy[hcPlanckSpeed/#,10., 0.015]&;

radius = 30.;
dataE = {{0,0},{0,0}};
lda = 342.;
indices = {1.33, nDrude[lda]};

mesh = N[Array[{#1,0.,#2}&,{50,50}, 3. * radius *{{1,-1},{1,-1}}]];
AbsoluteTiming[ dataE[[1,1]] = MieScatteredElectricField[mesh,indices, lda, radius,{1}, "Parallelize" -> True];]
AbsoluteTiming[ dataE[[1,2]] = MieInternalElectricField[mesh,indices, lda, radius, {1}, "Parallelize" -> True];]

mesh = N[Array[{0.,#1,#2}&,{50,50}, 3. * radius *{{1,-1},{1,-1}}]];
AbsoluteTiming[ dataE[[2,1]] = MieScatteredElectricField[mesh,indices, lda, radius,{1}, "Parallelize" -> True];]
AbsoluteTiming[ dataE[[2,2]] = MieInternalElectricField[mesh,indices, lda, radius, {1}, "Parallelize" -> True];]
# Out:
# {17.3813, Null}
# {2.16746, Null}
# {18.0912, Null}
# {2.45775, Null}

# %%
Map[ListDensityPlot[Map[Chop@Norm, #,{-2}], PlotLegends -> Automatic ]&, dataE, {2}]
Map[ListDensityPlot[Map[Chop@Norm, #,{-2}], PlotLegends -> Automatic]&, Plus @@@ dataE]
# Out:
# {{Legended[-Graphics-, Placed[BarLegend[{JetExtended[#1] & , {0., 5.84075}},
#
# >       LabelStyle -> {}, LegendLayout -> Column, LegendMarkerSize -> 215,
#
# >       ScalingFunctions -> {Identity, Identity}, Charting`TickSide -> Right,
#
# >       ColorFunctionScaling -> True], After, Identity]],
#
# >    Legended[-Graphics-, Placed[BarLegend[{JetExtended[#1] & , {0., 294.495}},
#
# >       LabelStyle -> {}, LegendLayout -> Column, LegendMarkerSize -> 215,
#
# >       ScalingFunctions -> {Identity, Identity}, Charting`TickSide -> Right,
#
# >       ColorFunctionScaling -> True], After, Identity]]},
#
# >   {Legended[-Graphics-, Placed[BarLegend[{JetExtended[#1] & , {0., 2.10048}},
#
# >       LabelStyle -> {}, LegendLayout -> Column, LegendMarkerSize -> 215,
#
# >       ScalingFunctions -> {Identity, Identity}, Charting`TickSide -> Right,
#
# >       ColorFunctionScaling -> True], After, Identity]],
#
# >    Legended[-Graphics-, Placed[BarLegend[{JetExtended[#1] & , {0., 191.56}},
# ...

# %%
nDrude = Sqrt@DrudeEpsEnergy[hcPlanckSpeed/#,10., 0.015]&;

radius = 30.;
dataM = {{0,0},{0,0}};
lda = 342.;
indices = {1.33, nDrude[lda]};

mesh = N[Array[{#1,0.,#2}&,{50,50}, 3. * radius *{{1,-1},{1,-1}}]];
AbsoluteTiming[ dataM[[1,1]] = MieScatteredHField[mesh,indices, lda, radius,{1}, "Parallelize" -> True];]
AbsoluteTiming[ dataM[[1,2]] = MieInternalHField[mesh,indices, lda, radius, {1}, "Parallelize" -> True];]

mesh = N[Array[{0.,#1,#2}&,{50,50}, 3. * radius *{{1,-1},{1,-1}}]];
AbsoluteTiming[ dataM[[2,1]] = MieScatteredHField[mesh,indices, lda, radius,{1}, "Parallelize" -> True];]
AbsoluteTiming[ dataM[[2,2]] = MieInternalHField[mesh,indices, lda, radius, {1}, "Parallelize" -> True];]
# Out:
# {17.8197, Null}
# {1.99928, Null}
# {17.4317, Null}
# {1.95299, Null}

# %%
Map[ListDensityPlot[Map[Chop@Norm, #,{-2}], PlotLegends -> Automatic]&, dataM, {2}]
Map[ListDensityPlot[Map[Chop@Norm, #,{-2}], PlotLegends -> Automatic]&, Plus @@@ dataM]
# Out:
# {{Legended[-Graphics-, Placed[BarLegend[{JetExtended[#1] & , {0., 2.1361}},
#
# >       LabelStyle -> {}, LegendLayout -> Column, LegendMarkerSize -> 215,
#
# >       ScalingFunctions -> {Identity, Identity}, Charting`TickSide -> Right,
#
# >       ColorFunctionScaling -> True], After, Identity]],
#
# >    Legended[-Graphics-, Placed[BarLegend[{JetExtended[#1] & , {0., 0.435765}},
#
# >       LabelStyle -> {}, LegendLayout -> Column, LegendMarkerSize -> 215,
#
# >       ScalingFunctions -> {Identity, Identity}, Charting`TickSide -> Right,
#
# >       ColorFunctionScaling -> True], After, Identity]]},
#
# >   {Legended[-Graphics-, Placed[BarLegend[{JetExtended[#1] & , {0., 2.24163}},
#
# >       LabelStyle -> {}, LegendLayout -> Column, LegendMarkerSize -> 215,
#
# >       ScalingFunctions -> {Identity, Identity}, Charting`TickSide -> Right,
#
# >       ColorFunctionScaling -> True], After, Identity]],
#
# ...

# %% [markdown]
# ## Cuadrupolo

# %%
nDrude = Sqrt@DrudeEpsEnergy[hcPlanckSpeed/#,10., 0.015]&;

radius = 30.;
dataE = {{0,0},{0,0}};
lda = 262.;
indices = {1.33, nDrude[lda]};

mesh = N[Array[{#1,0.,#2}&,{50,50}, 3. * radius *{{1,-1},{1,-1}}]];
AbsoluteTiming[ dataE[[1,1]] = MieScatteredElectricField[mesh,indices, lda, radius,{2}, "Parallelize" -> True];]
AbsoluteTiming[ dataE[[1,2]] = MieInternalElectricField[mesh,indices, lda, radius, {2}, "Parallelize" -> True];]

mesh = N[Array[{0.,#1,#2}&,{50,50}, 3. * radius *{{1,-1},{1,-1}}]];
AbsoluteTiming[ dataE[[2,1]] = MieScatteredElectricField[mesh,indices, lda, radius,{2}, "Parallelize" -> True];]
AbsoluteTiming[ dataE[[2,2]] = MieInternalElectricField[mesh,indices, lda, radius, {2}, "Parallelize" -> True];]
# Out:
# {18.4449, Null}
# {1.99986, Null}
# {17.4644, Null}
# {2.37721, Null}

# %%
Map[ListDensityPlot[Map[Chop@Norm, #,{-2}], PlotLegends -> Automatic ]&, dataE, {2}]
Map[ListDensityPlot[Map[Chop@Norm, #,{-2}], PlotLegends -> Automatic]&, Plus @@@ dataE]
# Out:
# {{Legended[-Graphics-, Placed[BarLegend[{JetExtended[#1] & , {0., 25.0696}},
#
# >       LabelStyle -> {}, LegendLayout -> Column, LegendMarkerSize -> 215,
#
# >       ScalingFunctions -> {Identity, Identity}, Charting`TickSide -> Right,
#
# >       ColorFunctionScaling -> True], After, Identity]],
#
# >    Legended[-Graphics-, Placed[BarLegend[{JetExtended[#1] & , {0., 86424.4}},
#
# >       LabelStyle -> {}, LegendLayout -> Column, LegendMarkerSize -> 215,
#
# >       ScalingFunctions -> {Identity, Identity}, Charting`TickSide -> Right,
#
# >       ColorFunctionScaling -> True], After, Identity]]},
#
# >   {Legended[-Graphics-, Placed[BarLegend[{JetExtended[#1] & , {0., 16.1484}},
#
# >       LabelStyle -> {}, LegendLayout -> Column, LegendMarkerSize -> 215,
#
# >       ScalingFunctions -> {Identity, Identity}, Charting`TickSide -> Right,
#
# >       ColorFunctionScaling -> True], After, Identity]],
#
# ...

# %%
nDrude = Sqrt@DrudeEpsEnergy[hcPlanckSpeed/#,10., 0.015]&;

radius = 30.;
dataM = {{0,0},{0,0}};
lda = 262.;
indices = {1.33, nDrude[lda]};

mesh = N[Array[{#1,0.,#2}&,{50,50}, 3. * radius *{{1,-1},{1,-1}}]];
AbsoluteTiming[ dataM[[1,1]] = MieScatteredHField[mesh,indices, lda, radius,{2}, "Parallelize" -> True];]
AbsoluteTiming[ dataM[[1,2]] = MieInternalHField[mesh,indices, lda, radius, {2}, "Parallelize" -> True];]

mesh = N[Array[{0.,#1,#2}&,{50,50}, 3. * radius *{{1,-1},{1,-1}}]];
AbsoluteTiming[ dataM[[2,1]] = MieScatteredHField[mesh,indices, lda, radius,{2}, "Parallelize" -> True];]
AbsoluteTiming[ dataM[[2,2]] = MieInternalHField[mesh,indices, lda, radius, {2}, "Parallelize" -> True];]
# Out:
# {18.0849, Null}
# {2.01731, Null}
# {17.3773, Null}
# {2.25405, Null}

# %%
Map[ListDensityPlot[Map[Chop@Norm, #,{-2}], PlotLegends -> Automatic]&, dataM, {2}]
Map[ListDensityPlot[Map[Chop@Norm, #,{-2}], PlotLegends -> Automatic]&, Plus @@@ dataM]
# Out:
# {{Legended[-Graphics-, Placed[BarLegend[{JetExtended[#1] & , {0., 9.72557}},
#
# >       LabelStyle -> {}, LegendLayout -> Column, LegendMarkerSize -> 215,
#
# >       ScalingFunctions -> {Identity, Identity}, Charting`TickSide -> Right,
#
# >       ColorFunctionScaling -> True], After, Identity]],
#
# >    Legended[-Graphics-, Placed[BarLegend[{JetExtended[#1] & , {0., 7.38055}},
#
# >       LabelStyle -> {}, LegendLayout -> Column, LegendMarkerSize -> 215,
#
# >       ScalingFunctions -> {Identity, Identity}, Charting`TickSide -> Right,
#
# >       ColorFunctionScaling -> True], After, Identity]]},
#
# >   {Legended[-Graphics-, Placed[BarLegend[{JetExtended[#1] & , {0., 9.77604}},
#
# >       LabelStyle -> {}, LegendLayout -> Column, LegendMarkerSize -> 215,
#
# >       ScalingFunctions -> {Identity, Identity}, Charting`TickSide -> Right,
#
# >       ColorFunctionScaling -> True], After, Identity]],
#
# ...

# %% [markdown]
# ## 12.5 Au in Air

# %%
mesh = N[Array[{#1,0.,#2}&,{75,75}, 3. * radius *{{1,-1},{1,-1}}]];

# %%
radius = 12.5;
nNP = JohnsonChristyAuRefSize[ #, radius ]&;

dataE = {{0,0},{0,0}};
lda = 507.;
indices = {1., nNP[lda]};

mesh = N[Array[{#1,0.,#2}&,{100,100}, 3. * radius *{{1,-1},{1,-1}}]];
AbsoluteTiming[ dataE[[1,1]] = MieScatteredElectricField[mesh,indices, lda, radius, "Parallelize" -> True];]
AbsoluteTiming[ dataE[[1,2]] = MieInternalElectricField[mesh,indices, lda, radius, "Parallelize" -> True];]

mesh = N[Array[{0.,#1,#2}&,{100,100}, 3. * radius *{{1,-1},{1,-1}}]];
AbsoluteTiming[ dataE[[2,1]] = MieScatteredElectricField[mesh,indices, lda, radius, "Parallelize" -> True];]
AbsoluteTiming[ dataE[[2,2]] = MieInternalElectricField[mesh,indices, lda, radius, "Parallelize" -> True];]

# %%
eNormAir = Map[Chop@Norm, Plus @@@ dataE ,{-2}] ;
plane = {"-XZ","-YZ"}
MapThread[ Export["4-ENorm-12nm5-Air"<>#1<>".csv", #2]&, {plane, eNormAir}]
# Out:
# {-XZ, -YZ}
# {4-ENorm-12nm5-Air-XZ.csv, 4-ENorm-12nm5-Air-YZ.csv}

# %%
radiusTicks = {radius*#,#}&/@Range[-3,3]
# Out:
# {{-37.5, -3}, {-25., -2}, {-12.5, -1}, {0., 0}, {12.5, 1}, {25., 2}, {37.5, 3}}

# %%
algo = ListDensityPlot[#, PlotLegends -> None, InterpolationOrder -> 1, DataRange -> {{-1,1},{-1,1}}*3*radius,ColorFunction -> ColorData["SunsetColors"],
    FrameTicks -> None] &/@ eNormAir;
algo = Show[{#, Graphics[{White,Thick,Dashed,Circle[{0,0},12.5]}]}] &/@ algo;
MapThread[ Export["4-NearField/Sunzet-ENorm-12nm5-Air"<>#1<>".svg", #2]&, {plane, algo}]

algo = ListDensityPlot[#, PlotLegends -> None, InterpolationOrder -> 1, DataRange -> {{-1,1},{-1,1}}*3*radius,
    FrameTicks -> None] &/@ eNormAir;
algo = Show[{#, Graphics[{White,Thick,Dashed,Circle[{0,0},12.5]}]}] &/@ algo;
MapThread[ Export["4-NearField/ENorm-12nm5-Air"<>#1<>".svg", #2]&, {plane, algo}]
# Out:
# {4-NearField/Sunzet-ENorm-12nm5-Air-XZ.svg, 4-NearField/Sunzet-ENorm-12nm5-Air-YZ.svg}

# %%
ListPlot[{0,0}, PlotRange -> {{-1,1},{-1,1}}*3*radius,
    BaseStyle -> texStyle, FrameStyle-> Black, AspectRatio -> 1,
    ImageSize -> 180, PlotRangePadding -> None,
    Frame-> True,
       FrameTicks -> {{Automatic, radiusTicks},{Automatic, radiusTicks}}
    ]  
Export["4-NearField/emptyFrame.pdf",%]
# Out:
# -Graphics-
# 4-NearField/emptyFrame.pdf

# %%
Plot[x, {x, #1, #2}, BaseStyle -> texStyle, 
  FrameTicks -> {{None, None}, {Automatic, None}},
  FrameStyle -> Black,    Frame-> True,
  AspectRatio -> 1/20, 
  PlotRange -> All, PlotRangePadding -> None, 
 ImageSize -> {60, 25}*2]& @@@  (MinMax /@ eNormAir)
 MapThread[ Export["4-NearField/FrameJet"<>#1<>".pdf", #2]&, {plane, %}]
# Out:
# {-Graphics-, -Graphics-}
# {4-NearField/FrameJet-XZ.pdf, 4-NearField/FrameJet-YZ.pdf}

# %%
dataE[[1,1]] // SliceVectorPlot3D[#, "CenterPlanes", {x, -2, 2}, {y, -2, 2}, {z, -2, 2}]&

# %%
DensityPlot[x, {x, #1, #2}, {y, 0, 1}, BaseStyle -> texStyle, 
  FrameTicks -> {{None, None}, {None, None}},
  FrameStyle -> Black, 
  AspectRatio -> 1/20, 
  PlotRange -> All, ColorFunction -> JetExtended, 
  PlotPoints -> 40, PlotRangePadding -> None, 
 ImageSize -> {60, 25}*2]& @@@  (MinMax /@ eNormAir)
 MapThread[ Export["4-NearField/ColorJet"<>#1<>".svg", #2]&, {plane, %}]
 
 DensityPlot[x, {x, #1, #2}, {y, 0, 1}, BaseStyle -> texStyle, 
  FrameTicks -> {{None, None}, {None, None}},
  FrameStyle -> Black, 
  AspectRatio -> 1/20, 
  PlotRange -> All, ColorFunction -> ColorData["SunsetColors"], 
  PlotPoints -> 40, PlotRangePadding -> None, 
 ImageSize -> {60, 25}*2]& @@@  (MinMax /@ eNormAir)
 MapThread[ Export["4-NearField/ColorSunset"<>#1<>".svg", #2]&, {plane, %}]
# Out:
# {-Graphics-, -Graphics-}
# {4-NearField/ColorJet-XZ.svg, 4-NearField/ColorJet-YZ.svg}
# {-Graphics-, -Graphics-}
# {4-NearField/ColorSunset-XZ.svg, 4-NearField/ColorSunset-YZ.svg}

# %% [markdown]
# ## 12.5 Au in Glass

# %%
nNP = JohnsonChristyAuRefSize[ #, radius ]&;

radius = 12.5;
dataE = {{0,0},{0,0}};
lda = 507.;
indices = {1.5, nNP[lda]};

mesh = N[Array[{#1,0.,#2}&,{100,100}, 3. * radius *{{1,-1},{1,-1}}]];
AbsoluteTiming[ dataE[[1,1]] = MieScatteredElectricField[mesh,indices, lda, radius, "Parallelize" -> True];]
AbsoluteTiming[ dataE[[1,2]] = MieInternalElectricField[mesh,indices, lda, radius, "Parallelize" -> True];]

mesh = N[Array[{0.,#1,#2}&,{100,100}, 3. * radius *{{1,-1},{1,-1}}]];
AbsoluteTiming[ dataE[[2,1]] = MieScatteredElectricField[mesh,indices, lda, radius, "Parallelize" -> True];]
AbsoluteTiming[ dataE[[2,2]] = MieInternalElectricField[mesh,indices, lda, radius, "Parallelize" -> True];]

# %%
Map[ListDensityPlot[Map[Chop@Norm, #,{-2}], PlotLegends -> Automatic ]&, dataE, {2}]
Map[ListDensityPlot[Map[Chop@Norm, #,{-2}], PlotLegends -> Automatic]&, Plus @@@ dataE]

# %%
nNP = JohnsonChristyAuRefSize[ #, radius ]&;

radius = 12.5;
dataE = {{0,0},{0,0}};
lda = 507.;
indices = {1.5, nNP[lda]};

mesh = N[Array[{#1,0.,#2}&,{100,100}, 3. * radius *{{1,-1},{1,-1}}]];
AbsoluteTiming[ dataE[[1,1]] = MieScatteredElectricField[mesh,indices, lda, radius, "Parallelize" -> True, 10];]
AbsoluteTiming[ dataE[[1,2]] = MieInternalElectricField[mesh,indices, lda, radius, "Parallelize" -> True, 10];]
# Out:
# {0.000011, Null}
# {0.000013, Null}

# %%
dataE
# Out:
# {{MieScatteredElectricField[{{{37.5, 0., 37.5}, {37.5, 0., 36.7424},
#
# >       {37.5, 0., 35.9848}, {37.5, 0., 35.2273}, {37.5, 0., 34.4697},
#
# >       {37.5, 0., 33.7121}, {37.5, 0., 32.9545}, {37.5, 0., 32.197},
#
# >       {37.5, 0., 31.4394}, {37.5, 0., 30.6818}, {37.5, 0., 29.9242},
#
# >       {37.5, 0., 29.1667}, {37.5, 0., 28.4091}, {37.5, 0., 27.6515},
#
# >       {37.5, 0., 26.8939}, {37.5, 0., 26.1364}, {37.5, 0., 25.3788},
#
# >       {37.5, 0., 24.6212}, {37.5, 0., 23.8636}, {37.5, 0., 23.1061},
#
# >       {37.5, 0., 22.3485}, {37.5, 0., 21.5909}, {37.5, 0., 20.8333},
#
# >       {37.5, 0., 20.0758}, {37.5, 0., 19.3182}, {37.5, 0., 18.5606},
#
# >       {37.5, 0., 17.803}, {37.5, 0., 17.0455}, {37.5, 0., 16.2879},
#
# >       {37.5, 0., 15.5303}, {37.5, 0., 14.7727}, {37.5, 0., 14.0152},
#
# >       {37.5, 0., 13.2576}, {37.5, 0., 12.5}, {37.5, 0., 11.7424}, {37.5, 0., 10.9848},
#
# >       {37.5, 0., 10.2273}, {37.5, 0., 9.4697}, {37.5, 0., 8.71212},
#
# ...
