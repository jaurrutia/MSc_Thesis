# %%
list = DeleteDuplicates@Sort@Join[Range[400,600,10.],
    Range[500,530,2.5]]
Export["wlength-air.txt",list]
# Out:
# {400., 410., 420., 430., 440., 450., 460., 470., 480., 490., 500., 502.5, 505., 507.5,
#
# >   510., 512.5, 515., 517.5, 520., 522.5, 525., 527.5, 530., 540., 550., 560., 570.,
#
# >   580., 590., 600.}
# wlength-air.txt

# %%
list = DeleteDuplicates@Sort@Join[Range[400,600,10.],
    Range[510,550,2.5]]

Export["wlength-glass.txt",list]
# Out:
# {400., 410., 420., 430., 440., 450., 460., 470., 480., 490., 500., 510., 512.5, 515.,
#
# >   517.5, 520., 522.5, 525., 527.5, 530., 532.5, 535., 537.5, 540., 542.5, 545., 547.5,
#
# >   550., 560., 570., 580., 590., 600.}
# wlength-glass.txt

# %%
list = DeleteDuplicates@Sort@Join[Range[400,600,10.],
    Range[520,560,2.5]]

Export["wlength-from-glass.txt",list]
